# %% [markdown]
# ![%E3%82%B9%E3%82%AF%E3%83%AA%E3%83%BC%E3%83%B3%E3%82%B7%E3%83%A7%E3%83%83%E3%83%88%202022-06-08%2014.53.08.png](attachment:%E3%82%B9%E3%82%AF%E3%83%AA%E3%83%BC%E3%83%B3%E3%82%B7%E3%83%A7%E3%83%83%E3%83%88%202022-06-08%2014.53.08.png)

# %% [markdown]
# ![%E3%82%B9%E3%82%AF%E3%83%AA%E3%83%BC%E3%83%B3%E3%82%B7%E3%83%A7%E3%83%83%E3%83%88%202022-06-08%2015.06.42.png](attachment:%E3%82%B9%E3%82%AF%E3%83%AA%E3%83%BC%E3%83%B3%E3%82%B7%E3%83%A7%E3%83%83%E3%83%88%202022-06-08%2015.06.42.png)

# %% [markdown]
# ## 1.
# 3つ以上の単語で構成される文章に対し，ある単語はその一つ前の単語及びそれ以前の単語に依存して決定するような言語現象は全てマルコフ連鎖でモデル化不可能である．

# %% [markdown]
# ***
# ## 2.
# $a_{kj} = P(t^k|t^j) = C(t^j, t^k) / C(t^j)$を用いて表10.3の値より計算する.

# %%
print('P(AT | PERIOD) =  C(AT, PERIOD)/C(AT) = ',  48636/(48636+19)  )
print('P(NN | AT) =  C(NN, AT)/C(NN) =',  1067/(1067+3720+42470+11773+614+21392))  
print('P(BEZ | NN) =  C(BEZ, NN)/C(BEZ) =',  187/(1973+426+187+38))  
print('P(IN | BEZ) =  C(IN, BEZ)/C(IN) =',  0/(43322+1325+17314+185))  
print('P(AT | IN) =  C(AT, IN)/C(AT) =',  0/(48636+19))  
print('P(PERIOD | NN) =  C(PERIOD, NN)/C(PERIOD) =',  1329/(8016+75+4656+1329+954))
# Out:
# P(AT | PERIOD) =  C(AT, PERIOD)/C(AT) =  0.999609495426986
# P(NN | AT) =  C(NN, AT)/C(NN) = 0.013166987511723184
# P(BEZ | NN) =  C(BEZ, NN)/C(BEZ) = 0.07126524390243902
# P(IN | BEZ) =  C(IN, BEZ)/C(IN) = 0.0
# P(AT | IN) =  C(AT, IN)/C(AT) = 0.0
# P(PERIOD | NN) =  C(PERIOD, NN)/C(PERIOD) = 0.08842315369261478

# %% [markdown]
# ***
# ## 3.
# $b_{kjl} = P(w^l | t^j) = C(w^l, t^j)/C(t^j)$を用いて表10.4の値より計算する.

# %%
print('P(bear | tk) = C(bear, VB)/C(VB) =',  43/(43+133))
print('P(is | tk) = C(is, BEZ)/C(BEZ) =',  10065/10065)
print('P(move | tk) = C(move, VB)/C(VB) =',  133/(43+133+4))
print('P(president | tk) = C(president, NN)/C(NN) =',  382/(10+36+381+108))
print('P(progress | tk) = C(progress, NN)/C(NN) =',  108/(10+36+381+108))
print('P(the | tk) = C(the, AT)/C(AT) =',  69016/69016)
# Out:
# P(bear | tk) = C(bear, VB)/C(VB) = 0.24431818181818182
# P(is | tk) = C(is, BEZ)/C(BEZ) = 1.0
# P(move | tk) = C(move, VB)/C(VB) = 0.7388888888888889
# P(president | tk) = C(president, NN)/C(NN) = 0.7140186915887851
# P(progress | tk) = C(progress, NN)/C(NN) = 0.20186915887850468
# P(the | tk) = C(the, AT)/C(AT) = 1.0
