# %% [markdown]
# ![%E3%82%B9%E3%82%AF%E3%83%AA%E3%83%BC%E3%83%B3%E3%82%B7%E3%83%A7%E3%83%83%E3%83%88%202022-05-23%2014.06.11-2.png](attachment:%E3%82%B9%E3%82%AF%E3%83%AA%E3%83%BC%E3%83%B3%E3%82%B7%E3%83%A7%E3%83%83%E3%83%88%202022-05-23%2014.06.11-2.png)

# %% [markdown]
# ## Assignment6-前半
# 図中の赤く塗られた領域内のある点aについてに注目する．
# まず直線f1(x)= f2(x)に注目すると，f1(a)<f2(a)となる．
# 次に直線f1(x)= f3(x)に注目すると，f1(a)<f3(a)となる．
# 次に直線f1(x)= f4(x)に注目すると，f4(a)<f1(a)となる．
# 次に直線f2(x)= f3(x)に注目すると，f2(a)<f3(a)となる．
# 次に直線f2(x)= f4(x)に注目すると，f4(a)<f2(a)となる．
# ここまでのまでの大小関係をまとめるとf4(a)<f1(a)<f2(a)<f3(a)となる．
#
# 最後に直線f3(x)= f4(x)に注目すると，f3(a)<f4(a)となるが，これはf4(a)<f1(a)<f2(a)<f3(a)から導かれるf4(a)<f3(a)と矛盾する．

# %% [markdown]
# ![%E3%82%B9%E3%82%AF%E3%83%AA%E3%83%BC%E3%83%B3%E3%82%B7%E3%83%A7%E3%83%83%E3%83%88%202022-05-23%2014.06.19.png](attachment:%E3%82%B9%E3%82%AF%E3%83%AA%E3%83%BC%E3%83%B3%E3%82%B7%E3%83%A7%E3%83%83%E3%83%88%202022-05-23%2014.06.19.png)

# %% [markdown]
# ## Assignment6-後半
# 分かりませんでした．
