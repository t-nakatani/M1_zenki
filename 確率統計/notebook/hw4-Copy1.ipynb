# %% [markdown]
# ## 課題1
# ![%E3%82%B9%E3%82%AF%E3%83%AA%E3%83%BC%E3%83%B3%E3%82%B7%E3%83%A7%E3%83%83%E3%83%88%202022-05-18%209.50.13.png](attachment:%E3%82%B9%E3%82%AF%E3%83%AA%E3%83%BC%E3%83%B3%E3%82%B7%E3%83%A7%E3%83%83%E3%83%88%202022-05-18%209.50.13.png)

# %%
import numpy as np
import matplotlib.pyplot as plt
arr = np.random.uniform(0, 1, 10000)
arr_ = np.array([1 if val <= 0.4 else 0 for val in arr_])
mean_arr = [sum_/(i+1) for i, sum_ in enumerate(np.cumsum(arr_))]

# %%
num_try = np.arange(10000)+1

# %%
plt.figure(figsize=(12,8))
plt.plot(num_try, mean_arr)
plt.ylim([0.1, 0.7])
plt.show()

# %% [markdown]
# ## 課題2
# ![%E3%82%B9%E3%82%AF%E3%83%AA%E3%83%BC%E3%83%B3%E3%82%B7%E3%83%A7%E3%83%83%E3%83%88%202022-05-18%209.49.56.png](attachment:%E3%82%B9%E3%82%AF%E3%83%AA%E3%83%BC%E3%83%B3%E3%82%B7%E3%83%A7%E3%83%83%E3%83%88%202022-05-18%209.49.56.png)

# %%
# Out:
#              0         1         2         3
# 0    -0.893643  0.889307  1.157989  0.957448
# 1     0.594872 -0.205208  0.957812  0.990068
# 2     0.514858  0.775194  1.512332  1.034744
# 3     5.574586  1.492186  1.065444  0.931068
# 4     2.186736  0.918410  1.190238  1.466409
# ...        ...       ...       ...       ...
# 9995  1.578218  0.597162  0.201510  0.613398
# 9996 -0.590464  1.043021  1.724941  1.230011
# 9997  0.188174  0.083211  0.456708  0.732220
# 9998 -0.455849 -0.288990  0.926674  0.869983
# 9999 -0.140043  1.281665  0.772975  0.844772
#
# [10000 rows x 4 columns]

# %%
labels = ['Y1', 'Y5', 'Y25', 'Y125']
n_bins = 50
plt.figure(figsize=(12, 8))
for i, num, label in zip(range(4), [1, 5, 25, 125], labels):
    hy, bins = np.histogram(df[i], bins=n_bins, density=True)
#     hy = hy/N*n_bins # n/N*(range/bins)

    hx = bins[:-1] + np.diff(bins)/2
    plt.plot(hx,hy, label=label)
plt.legend()
plt.show()

# %%
bins
# Out:
# array([0.41345858, 0.44021666, 0.46697474, 0.49373282, 0.5204909 ,
#        0.54724898, 0.57400706, 0.60076514, 0.62752322, 0.6542813 ,
#        0.68103938, 0.70779746, 0.73455554, 0.76131362, 0.7880717 ,
#        0.81482978, 0.84158786, 0.86834594, 0.89510402, 0.9218621 ,
#        0.94862018, 0.97537826, 1.00213634, 1.02889442, 1.0556525 ,
#        1.08241058, 1.10916866, 1.13592674, 1.16268482, 1.1894429 ,
#        1.21620098, 1.24295906, 1.26971714, 1.29647522, 1.3232333 ,
#        1.34999138, 1.37674946, 1.40350754, 1.43026562, 1.4570237 ,
#        1.48378178, 1.51053986, 1.53729794, 1.56405602, 1.5908141 ,
#        1.61757218, 1.64433026, 1.67108834, 1.69784642, 1.7246045 ,
#        1.75136258])

# %%
list_poisson
mean_arr = [sum_/(i+1) for i, sum_ in enumerate(np.cumsum(list_poisson))]

# %%
n_bins = 50
hy, bins = np.histogram(mean_arr, bins = n_bins*(i+1))
hy = hy/10000*n_bins*(i+1)/(bins[-1]-bins[0]) # n/N*(range/bins)
hx = bins[:-1] + np.diff(bins)/2
plt.plot(hx,hy)
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
bins
# Out:
# array([3.95316013, 3.95316322, 3.95316632, ..., 5.49999381, 5.49999691,
#        5.5       ])

# %%
#グラフ描画(青: 数値的に求めた確率, オレンジ: $\frac{e^{-\lambda}\lambda^k}{k!}$)  
import matplotlib.pyplot as plt
plt.figure(figsize=(12, 8))
plt.scatter(x, y1)
plt.scatter(x, y2)
plt.xticks(x)
plt.show()

# %% [markdown]
# ## 参考
# [PythonのCounterでリストの各要素の出現個数をカウント](https://note.nkmk.me/python-collections-counter/)
